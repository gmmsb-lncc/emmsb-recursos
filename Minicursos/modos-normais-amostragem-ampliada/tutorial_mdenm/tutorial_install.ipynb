# %% [markdown]
# # INSTALLATION INSTRUCTIONS

# %% [markdown]
# ### Install R and other libraries

# %%
#run in a Linux terminal
apt install r-base muscle libxml2-devel \
            libcurl-devel

# %% [markdown]
# ### Please install NAMD Install and set it in the PATH

# %% [markdown]
# ### Install miniconda

# %%
mkdir -p ~/miniconda3
wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O ~/miniconda3/miniconda.sh
bash ~/miniconda3/miniconda.sh -b -u -p ~/miniconda3
rm -rf ~/miniconda3/miniconda.sh

~/miniconda3/bin/conda init bash

# %% [markdown]
# ### Create enviroment

# %%
conda env create -f tutorial.yml

# %%
#alternavely (if is not in Linux or if you have errors with the previous command)
sh create_env.sh

# %% [markdown]
# ### Activate the enviroment

# %%
conda activate tutorial

# %%
#create R Kernel for the jupyter notebook
#run in a Linux terminal
R -e 'IRkernel::installspec()'

# %%
#run jupyter-notebook
jupyter-notebook

# %% [markdown]
# ### Open the tutorial_install.ipynb

# %%
install.packages("bio3d", dependencies=TRUE)
# Out:
# Warning message:
# “dependências ‘msa’, ‘Biostrings’ não estão disponíveis”
# instalando as dependências ‘rappdirs’, ‘sys’, ‘cachem’, ‘memoise’, ‘sass’, ‘fs’, ‘pkgbuild’, ‘rprojroot’, ‘diffobj’, ‘rematch2’, ‘tibble’, ‘askpass’, ‘bitops’, ‘magrittr’, ‘Matrix’, ‘pkgconfig’, ‘cpp11’, ‘bigmemory.sri’, ‘BH’, ‘highr’, ‘xfun’, ‘yaml’, ‘bslib’, ‘fontawesome’, ‘jquerylib’, ‘tinytex’, ‘brio’, ‘callr’, ‘desc’, ‘pkgload’, ‘praise’, ‘processx’, ‘ps’, ‘R6’, ‘waldo’, ‘withr’, ‘curl’, ‘mime’, ‘openssl’, ‘Rcpp’, ‘XML’, ‘RCurl’, ‘lattice’, ‘ncdf4’, ‘igraph’, ‘bigmemory’, ‘knitr’, ‘rmarkdown’, ‘testthat’, ‘httr’ também

# %%
install.packages("ggplot2", dependencies=TRUE)
# Out:
# instalando as dependências ‘backports’, ‘proxy’, ‘lazyeval’, ‘checkmate’, ‘rstudioapi’, ‘zoo’, ‘stringi’, ‘e1071’, ‘class’, ‘KernSmooth’, ‘wk’, ‘farver’, ‘labeling’, ‘viridisLite’, ‘rex’, ‘generics’, ‘tidyselect’, ‘cluster’, ‘nnet’, ‘foreign’, ‘gridExtra’, ‘data.table’, ‘htmlTable’, ‘viridis’, ‘colorspace’, ‘Formula’, ‘mvtnorm’, ‘survival’, ‘TH.data’, ‘sandwich’, ‘codetools’, ‘htmlwidgets’, ‘purrr’, ‘stringr’, ‘SparseM’, ‘MatrixModels’, ‘systemfonts’, ‘textshaping’, ‘classInt’, ‘DBI’, ‘s2’, ‘units’, ‘gtable’, ‘isoband’, ‘MASS’, ‘mgcv’, ‘scales’, ‘covr’, ‘dplyr’, ‘ggplot2movies’, ‘hexbin’, ‘Hmisc’, ‘mapproj’, ‘maps’, ‘multcomp’, ‘munsell’, ‘nlme’, ‘profvis’, ‘quantreg’, ‘ragg’, ‘RColorBrewer’, ‘rpart’, ‘sf’, ‘svglite’, ‘vdiffr’, ‘xml2’ também
#
#
# Warning message in install.packages("ggplot2", dependencies = TRUE):
# “instalação do pacote ‘stringi’ teve um status de saída não zero”
# Warning message in install.packages("ggplot2", dependencies = TRUE):
# ...
